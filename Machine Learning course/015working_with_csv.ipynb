# %% [markdown]
# # 1. Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# # Opening a local csv file

# %%
df = pd.read_csv("placement.csv") 
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# # 3. Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://github.com/DevanshuSinghRawat/CreditRisk-Logistic-Regression/blob/main/credit_risk.csv"

headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # 4. Separate parameter

# %%
# pd.read_csv('credit_risk.tsv', sep ='\t',names=['sno','over_draft','credit_usage','credit_history','purpose','current_balance'])

# %% [markdown]
# # 5.index_col parameter

# %%
pd.read_csv('credit_risk.csv')
# Out:
#       over_draft  credit_usage                  credit_history  \
# 0             <0             6  critical/other existing credit
# 1       0<=X<200            48                   existing paid
# 2    no checking            12  critical/other existing credit
# 3             <0            42                   existing paid
# 4             <0            24              delayed previously
# ..           ...           ...                             ...
# 995  no checking            12                   existing paid
# 996           <0            30                   existing paid
# 997  no checking            12                   existing paid
# 998           <0            45                   existing paid
# 999     0<=X<200            45  critical/other existing credit
#
#                  purpose  current_balance Average_Credit_Balance  employment  \
# 0               radio/tv             1169       no known savings         >=7
# ...

# %% [markdown]
# # 6. Header parameter}

# %%
pd.read_csv('placement.csv',header=1)
# Out:
#      0  6.8  123.0  1
# 0    1  5.9  106.0  0
# 1    2  5.3  121.0  0
# 2    3  7.4  132.0  1
# 3    4  5.8  142.0  0
# 4    5  7.1   48.0  1
# ..  ..  ...    ... ..
# 94  95  4.3  200.0  0
# 95  96  4.4   42.0  0
# 96  97  6.7  182.0  1
# 97  98  6.3  103.0  1
# 98  99  6.2  113.0  1
#
# [99 rows x 4 columns]

# %% [markdown]
# # 7. use_cols parameter

# %%
pd.read_csv('credit_risk.csv',usecols=['over_draft','credit_history'])
# Out:
#       over_draft                  credit_history
# 0             <0  critical/other existing credit
# 1       0<=X<200                   existing paid
# 2    no checking  critical/other existing credit
# 3             <0                   existing paid
# 4             <0              delayed previously
# ..           ...                             ...
# 995  no checking                   existing paid
# 996           <0                   existing paid
# 997  no checking                   existing paid
# 998           <0                   existing paid
# 999     0<=X<200  critical/other existing credit
#
# [1000 rows x 2 columns]

# %% [markdown]
# # 8. Squeeze parameter

# %%
pd.read_csv('credit_risk.csv',usecols=['over_draft'],squeeze=True)
# Out:
# 0               <0
# 1         0<=X<200
# 2      no checking
# 3               <0
# 4               <0
#           ...
# 995    no checking
# 996             <0
# 997    no checking
# 998             <0
# 999       0<=X<200
# Name: over_draft, Length: 1000, dtype: object

# %% [markdown]
# # 9. Skiprows/nrows Parameter

# %%
pd.read_csv('credit_risk.csv',skiprows=[0,1])
# Out:
#         0<=X<200  48                   existing paid             radio/tv  \
# 0    no checking  12  critical/other existing credit            education
# 1             <0  42                   existing paid  furniture/equipment
# 2             <0  24              delayed previously              new car
# 3    no checking  36                   existing paid            education
# 4    no checking  24                   existing paid  furniture/equipment
# ..           ...  ..                             ...                  ...
# 993  no checking  12                   existing paid  furniture/equipment
# 994           <0  30                   existing paid             used car
# 995  no checking  12                   existing paid             radio/tv
# 996           <0  45                   existing paid             radio/tv
# 997     0<=X<200  45  critical/other existing credit             used car
#
#      5951              <100      1<=X<4  2  female div/dep/mar       none  \
# ...

# %%
pd.read_csv('credit_risk.csv',skiprows=[0,5])
# Out:
#               <0   6  critical/other existing credit             radio/tv  \
# 0       0<=X<200  48                   existing paid             radio/tv
# 1    no checking  12  critical/other existing credit            education
# 2             <0  42                   existing paid  furniture/equipment
# 3    no checking  36                   existing paid            education
# 4    no checking  24                   existing paid  furniture/equipment
# ..           ...  ..                             ...                  ...
# 993  no checking  12                   existing paid  furniture/equipment
# 994           <0  30                   existing paid             used car
# 995  no checking  12                   existing paid             radio/tv
# 996           <0  45                   existing paid             radio/tv
# 997     0<=X<200  45  critical/other existing credit             used car
#
#      1169  no known savings         >=7  4         male single       none  \
# ...

# %%
pd.read_csv('credit_risk.csv',nrows=10)
# Out:
#     over_draft  credit_usage                  credit_history  \
# 0           <0             6  critical/other existing credit
# 1     0<=X<200            48                   existing paid
# 2  no checking            12  critical/other existing credit
# 3           <0            42                   existing paid
# 4           <0            24              delayed previously
# 5  no checking            36                   existing paid
# 6  no checking            24                   existing paid
# 7     0<=X<200            36                   existing paid
# 8  no checking            12                   existing paid
# 9     0<=X<200            30  critical/other existing credit
#
#                purpose  current_balance Average_Credit_Balance  employment  \
# 0             radio/tv             1169       no known savings         >=7
# 1             radio/tv             5951                   <100      1<=X<4
# ...

# %% [markdown]
# # 10 Encoding parameter

# %%
pd.read_csv('credit_risk.csv', encoding ='latin-1')
# Out:
#       over_draft  credit_usage                  credit_history  \
# 0             <0             6  critical/other existing credit
# 1       0<=X<200            48                   existing paid
# 2    no checking            12  critical/other existing credit
# 3             <0            42                   existing paid
# 4             <0            24              delayed previously
# ..           ...           ...                             ...
# 995  no checking            12                   existing paid
# 996           <0            30                   existing paid
# 997  no checking            12                   existing paid
# 998           <0            45                   existing paid
# 999     0<=X<200            45  critical/other existing credit
#
#                  purpose  current_balance Average_Credit_Balance  employment  \
# 0               radio/tv             1169       no known savings         >=7
# ...

# %% [markdown]
# # 11. Skip bad lines

# %%
pd.read_csv('credit_risk.csv',sep =';', encoding ='latin-1',error_bad_lines =False)
# Out:
#     over_draft,credit_usage,credit_history,purpose,current_balance,Average_Credit_Balance,employment,location,personal_status,other_parties,residence_since,property_magnitude,cc_age,other_payment_plans,housing,existing_credits,job,num_dependents,own_telephone,foreign_worker,class
# 0    <0,6,"critical/other existing credit",radio/tv...
# 1    0<=X<200,48,"existing paid",radio/tv,5951,"<10...
# 2    no checking,12,"critical/other existing credit...
# 3    <0,42,"existing paid",furniture/equipment,7882...
# 4    <0,24,"delayed previously","new car",4870,"<10...
# ..                                                 ...
# 995  no checking,12,"existing paid",furniture/equip...
# 996  <0,30,"existing paid","used car",3857,"<100","...
# 997  no checking,12,"existing paid",radio/tv,804,"<...
# 998  <0,45,"existing paid",radio/tv,1845,"<100","1<...
# 999  0<=X<200,45,"critical/other existing credit","...
#
# [1000 rows x 1 columns]

# %% [markdown]
# # 12. dtypes parameter

# %%
pd.read_csv('aug_train.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
pd.read_csv('aug_train.csv',dtype ={'target':int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int32
# ...

# %% [markdown]
# # 13. Handling Dates

# %%
pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# # 14. Convertors

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

# %%
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
pd.read_csv('IPL Matches 2008-2020.csv',converters={'team1':rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # 15. na_values parameter

# %%
pd.read_csv('aug_train.csv',na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('aug_train.csv',chunksize = 5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
